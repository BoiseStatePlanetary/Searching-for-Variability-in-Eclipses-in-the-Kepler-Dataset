# %% [markdown]
# 2018 Oct 6<br>
# Setting up an analysis of Kepler-76 b using DFM's emcee package

# %%
# %matplotlib inline
#%load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt

from astropy import units as u

from statsmodels.robust.scale import mad
from scipy.optimize import curve_fit
from numpy.random import normal

from lightkurve import KeplerLightCurveFile

from evilmc import evparams, evmodel, convert_Kz
from transit_utils import bindata, transit_duration
from variable_eclipses_utils import *

from BEER_curve import BEER_curve

import emcee
from emcee.autocorr import integrated_time

K76 = Kepler76_params()

# %%
num_period = 1
binsize = 30./60./24.
    
# Retrieve while masking out transit
time, flux, filtered_time, filtered_flux = retreive_data(K76.saved_ep.per, num_periods=num_period, 
                                                         KIC=K76.KIC, fit_bottom=True, params=K76.saved_ep, 
                                                         drop_outliers=True)
folded_time = filtered_time % K76.saved_ep.per

# Estimate scatter
ind = ~transit_indices(folded_time, 2.*K76.dur, K76.T0)
unbinned_noise = mad(filtered_flux[ind])
print(unbinned_noise*1e6)
# Out:
# 141.83679022846894

# %%
# Initial fit using Faigler's parameters (with my own T0)
plt.plot(filtered_time, filtered_flux, 'b.')

# %%
def fit_all_signals(cur_time, cur_p, cur_b, cur_T0, cur_Aellip, cur_Abeam, cur_F0, cur_Aplanet, cur_phase_shift):
    params = K76.saved_params.copy()
    
    params['p'] = cur_p
    params['b'] = cur_b
    params['T0'] = cur_T0
    params['Aellip'] = cur_Aellip
    params['Abeam'] = cur_Abeam
    params['F0'] = cur_F0
    params['Aplanet'] = cur_Aplanet
    params['phase_shift'] = cur_phase_shift
    
    cur_BC = BEER_curve(cur_time, params, supersample_factor=10, exp_time=30./60./24.)
    
    return cur_BC.all_signals()

# %%
plt.plot(folded_time, fit_all_signals(folded_time, K76.saved_params['p'], K76.saved_params['b'], 
                                      K76.saved_params['T0'], K76.saved_params['Aellip'], K76.saved_params['Abeam'], 
                                      K76.saved_params['F0'], K76.saved_params['Aplanet'], 
                                      K76.saved_params['phase_shift']) ,'b.')

# %%
bounds = ([0., -1, K76.T0*0.95, -500e-6, -500e-6, -500e-6, -500e-6, -1], 
          [0.2, 1., K76.T0*1.05, 500e-6, 500e-6, 500e-6, 500e-6, 1])

def lnprior(theta):
    accept = True
    for i in range(len(theta)):
        accept = accept & (theta[i] > bounds[0][i] < theta[i] < bounds[1][i])

    if(accept):
        return 0.
    else:
        return -np.inf

def lnlike(theta, time, data, err):
    model = fit_all_signals(time, *theta)
    inv_sigma2 = 1.0/(err**2)
    return -0.5*(np.sum((data - model)**2*inv_sigma2))

def lnprob(theta, time, data, err):
    lp = lnprior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + lnlike(theta, time, data, err)

# %%
# Estimate scatter
ind = ~transit_indices(folded_time, K76.dur, K76.T0)
unbinned_noise = mad(filtered_flux[ind])

time = folded_time
data = filtered_flux
err = unbinned_noise*np.ones_like(folded_time)

initial_guess = [K76.saved_params['p'], K76.saved_params['b'], K76.saved_params['T0'],
                 K76.saved_params['Aellip'], K76.saved_params['Abeam'], K76.saved_params['F0'], 
                 K76.saved_params['Aplanet'], K76.saved_params['phase_shift']]
# popt, pcov = curve_fit(fit_all_signals, time, data, sigma=unbinned_noise*np.ones_like(time), p0=initial_guess, 
#                        bounds=bounds)
uncertainty = np.sqrt(pcov.diagonal())

ndim, nwalkers = len(initial_guess), 100
pos = [popt + uncertainty*np.random.randn(ndim) for i in range(nwalkers)]

# %%
sampler = emcee.EnsembleSampler(nwalkers, ndim, lnprob, args=(time, data, err))
# %time sampler.run_mcmc(pos, 5000)

print(np.std(sampler.chain[:, :, 0].reshape((-1, ndim))))
# Out:
# emcee: Exception while calling your likelihood function:
#   params: [ 1.04446799e-01  9.58203578e-01  6.85003359e-01  1.27134640e-05
#   4.43853001e-06  3.22182436e-05  1.76342900e-06 -2.49927303e-01]
#   args: (array([0.19340814, 0.21384281, 0.23427739, ..., 1.22867331, 1.24910778,
#        1.26954245]), array([-3.01982459e-05,  5.87374002e-06,  1.06597324e-04, ...,
#         1.97761915e-04, -1.29038795e-03, -2.00637986e-04]), array([0.00014346, 0.00014346, 0.00014346, ..., 0.00014346, 0.00014346,
#        0.00014346]))
#   kwargs: {}
#   exception:
# Traceback (most recent call last):
#   File "/Users/brian/anaconda/lib/python2.7/site-packages/emcee/ensemble.py", line 519, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#   File "<ipython-input-34-0511b02b8ff7>", line 23, in lnprob
#     return lp + lnlike(theta, time, data, err)
#   File "<ipython-input-34-0511b02b8ff7>", line 15, in lnlike
#     model = fit_all_signals(time, *theta)
#   File "<ipython-input-11-22610632642a>", line 15, in fit_all_signals
#     return cur_BC.all_signals()
#   File "/Users/brian/anaconda/lib/python2.7/site-packages/BEER_curve/BEER_curve.py", line 231, in all_signals
#     transit = self._transit() - 1.
#   File "/Users/brian/anaconda/lib/python2.7/site-packages/BEER_curve/BEER_curve.py", line 180, in _transit
#     return ma.evaluate(time)
#   File "/Users/brian/anaconda/lib/python2.7/site-packages/PyAstronomy/modelSuite/XTran/forTrans/mandelAgol.py", line 168, in evaluate
#     self._calcZList(time - self["T0"])
#   File "/Users/brian/anaconda/lib/python2.7/site-packages/PyAstronomy/modelSuite/XTran/circKepZList.py", line 40, in _zlistCirc
#     phase = time/self["per"]; phase -= numpy.floor(phase)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-47d27e2fa169> in <module>()
#       1 sampler = emcee.EnsembleSampler(nwalkers, ndim, lnprob, args=(time, data, err))
# ----> 2 get_ipython().magic(u'time sampler.run_mcmc(pos, 5000)')
#       3
#       4 print(np.std(sampler.chain[:, :, 0].reshape((-1, ndim))))
#
# /Users/brian/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /Users/brian/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-59> in time(self, line, cell, local_ns)
#
# /Users/brian/anaconda/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /Users/brian/anaconda/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1179         if mode=='eval':
#    1180             st = clock2()
# -> 1181             out = eval(code, glob, local_ns)
#    1182             end = clock2()
#    1183         else:
#
# <timed eval> in <module>()
#
# /Users/brian/anaconda/lib/python2.7/site-packages/emcee/sampler.pyc in run_mcmc(self, pos0, N, rstate0, lnprob0, **kwargs)
#     170
#     171         for results in self.sample(pos0, lnprob0, rstate0, iterations=N,
# --> 172                                    **kwargs):
#     173             pass
#     174
#
# /Users/brian/anaconda/lib/python2.7/site-packages/emcee/ensemble.pyc in sample(self, p0, lnprob0, rstate0, blobs0, iterations, thin, storechain, mh_proposal)
#     257                 for S0, S1 in [(first, second), (second, first)]:
#     258                     q, newlnp, acc, blob = self._propose_stretch(p[S0], p[S1],
# --> 259                                                                  lnprob[S0])
#     260                     if np.any(acc):
#     261                         # Update the positions, log probabilities and
#
# /Users/brian/anaconda/lib/python2.7/site-packages/emcee/ensemble.pyc in _propose_stretch(self, p0, p1, lnprob0)
#     330         # Calculate the proposed positions and the log-probability there.
#     331         q = c[rint] - zz[:, np.newaxis] * (c[rint] - s)
# --> 332         newlnprob, blob = self._get_lnprob(q)
#     333
#     334         # Decide whether or not the proposals should be accepted.
#
# /Users/brian/anaconda/lib/python2.7/site-packages/emcee/ensemble.pyc in _get_lnprob(self, pos)
#     380
#     381         # Run the log-probability calculations (optionally in parallel).
# --> 382         results = list(M(self.lnprobfn, [p[i] for i in range(len(p))]))
#     383
#     384         try:
#
# /Users/brian/anaconda/lib/python2.7/site-packages/emcee/ensemble.pyc in __call__(self, x)
#     517     def __call__(self, x):
#     518         try:
# --> 519             return self.f(x, *self.args, **self.kwargs)
#     520         except:
#     521             import traceback
#
# <ipython-input-34-0511b02b8ff7> in lnprob(theta, time, data, err)
#      21     if not np.isfinite(lp):
#      22         return -np.inf
# ---> 23     return lp + lnlike(theta, time, data, err)
#
# <ipython-input-34-0511b02b8ff7> in lnlike(theta, time, data, err)
#      13
#      14 def lnlike(theta, time, data, err):
# ---> 15     model = fit_all_signals(time, *theta)
#      16     inv_sigma2 = 1.0/(err**2)
#      17     return -0.5*(np.sum((data - model)**2*inv_sigma2))
#
# <ipython-input-11-22610632642a> in fit_all_signals(cur_time, cur_p, cur_b, cur_T0, cur_Aellip, cur_Abeam, cur_F0, cur_Aplanet, cur_phase_shift)
#      13     cur_BC = BEER_curve(cur_time, params, supersample_factor=10, exp_time=30./60./24.)
#      14
# ---> 15     return cur_BC.all_signals()
#
# /Users/brian/anaconda/lib/python2.7/site-packages/BEER_curve/BEER_curve.pyc in all_signals(self)
#     229         time = self.time
#     230
# --> 231         transit = self._transit() - 1.
#     232         eclipse = self._eclipse()
#     233
#
# /Users/brian/anaconda/lib/python2.7/site-packages/BEER_curve/BEER_curve.pyc in _transit(self)
#     178         ma = self.ma
#     179
# --> 180         return ma.evaluate(time)
#     181
#     182     def _eclipse(self):
#
# /Users/brian/anaconda/lib/python2.7/site-packages/PyAstronomy/modelSuite/XTran/forTrans/mandelAgol.pyc in evaluate(self, time)
#     166     # into a projected, normalized distance (z-parameter)
#     167     if self._orbit == "circular":
# --> 168       self._calcZList(time - self["T0"])
#     169     else:
#     170       # The orbit is keplerian
#
# /Users/brian/anaconda/lib/python2.7/site-packages/PyAstronomy/modelSuite/XTran/circKepZList.pyc in _zlistCirc(self, time)
#      38     alpha=(90.0-self["i"])/180.0*numpy.pi
#      39     # Determine the phases (to ensure that the secondary eclipse is not considered)
# ---> 40     phase = time/self["per"]; phase -= numpy.floor(phase)
#      41     # In these cases the 'planet' will be in front of the primary
#      42     self._intrans = numpy.where( numpy.logical_or( phase > 0.75, phase < 0.25 ) )[0]
#
# KeyboardInterrupt:

# %%
plt.plot(sampler.chain[:,:,5].reshape((-1, ndim)) + sampler.chain[:,:,6].reshape((-1, ndim)))
#plt.plot(sampler.chain[:,:,7].reshape((-1, ndim)))
#plt.axhline(K76.phase_shift)
# Out:
# [<matplotlib.lines.Line2D at 0x11e806c90>,
#  <matplotlib.lines.Line2D at 0x11e806e90>,
#  <matplotlib.lines.Line2D at 0x11e806fd0>,
#  <matplotlib.lines.Line2D at 0x11e812150>,
#  <matplotlib.lines.Line2D at 0x11e812290>,
#  <matplotlib.lines.Line2D at 0x11e8123d0>,
#  <matplotlib.lines.Line2D at 0x11e812510>,
#  <matplotlib.lines.Line2D at 0x11e812650>]

# %%
dist = sampler.chain[:,:,5].reshape((-1, ndim)) + sampler.chain[:,:,6].reshape((-1, ndim))
hst, bin_edges = np.histogram(dist, bins='auto')

plt.plot(bin_edges[1:], hst)

# %%
tm = integrated_time(dist)
print(tm)
# Out:
# ---------------------------------------------------------------------------
# AutocorrError                             Traceback (most recent call last)
# <ipython-input-63-63cb63627110> in <module>()
# ----> 1 tm = integrated_time(dist)
#       2 print(tm)
#
# /Users/brian/anaconda/lib/python2.7/site-packages/emcee/autocorr.pyc in integrated_time(x, low, high, step, c, full_output, axis, fast)
#     116             break
#     117
# --> 118     raise AutocorrError("The chain is too short to reliably estimate "
#     119                         "the autocorrelation time")
#     120
#
# AutocorrError: The chain is too short to reliably estimate the autocorrelation time
